# %%
import os
# 二次确认当前目录是否正确 (必须在 MiniOneRec-2 根目录下)
if not os.path.exists("data/amazon18_data_process.py"):
    # 尝试自动修正
    if os.path.exists("../../../data/amazon14_data_process.py"):
        os.chdir("../../..")
        print("已自动切换回项目根目录")
    else:
        raise FileNotFoundError(f"错误：当前工作目录是 {os.getcwd()}，找不到 data/amazon18_data_process.py。请先运行 [Cell 1] 切换到项目根目录！")
# 定义数据集名称
DATASET = "Beauty"
# 用户指定的数据源路径
RAW_DATA_PATH = "../MiniOneRec-2/data/Amazon/raw"  # 假设 MiniOneRec-2 与当前项目同级
# 或者如果是绝对路径，请按需修改，例如: RAW_DATA_PATH = "/home/user/MiniOneRec-2/data/Amazon/raw"
# 运行数据处理脚本
# !python data/amazon14_data_process.py \
    --dataset {DATASET} \
    --user_k 5 \
    --item_k 5 \
    --st_year 1996 --st_month 10 \
    --ed_year 2014 --ed_month 10 \
    --reviews_file {RAW_DATA_PATH}/{DATASET}_5.json \
    --metadata_file {RAW_DATA_PATH}/meta_{DATASET}.json \
    --output_path ./data/Amazon
print(f"{DATASET} 数据处理完成！请检查 data/Amazon/{DATASET} 目录。")
# Out:
# /root/miniconda3/envs/leejt/lib/python3.12/site-packages/torch/_subclasses/functional_tensor.py:279: UserWarning: Failed to initialize NumPy: module 'numpy._globals' has no attribute '_signature_descriptor' (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:81.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))
# Processing dataset: Beauty
# Time range: 1996-10 to 2014-10
# K-core threshold: 5
# Loading metadata...
# Processing metadata: 100%|██████████| 259204/259204 [00:01<00:00, 205850.95it/s]
# Loaded 259204 metadata items. (258760 valid titles)
# Loading reviews...
# Loaded 198502 total reviews
# K-core filtering (Batch 1): 100%|██| 198502/198502 [00:00<00:00, 1142525.47it/s]
# Batch 1: Users: 22363, Items: 12094, Reviews: 198371
#   Removed in this batch - Users: 29, Items: 0
# K-core filtering (Batch 2): 100%|██| 198371/198371 [00:00<00:00, 1195779.67it/s]
# Batch 2: Users: 22334, Items: 12094, Reviews: 198255
# ...

# %%
import os
# 二次确认当前目录是否正确 (必须在 MiniOneRec-2 根目录下)
if not os.path.exists("data/amazon18_data_process.py"):
    # 尝试自动修正
    if os.path.exists("../../../data/amazon18_data_process.py"):
        os.chdir("../../..")
        print("已自动切换回项目根目录")
    else:
        raise FileNotFoundError(f"错误：当前工作目录是 {os.getcwd()}，找不到 data/amazon18_data_process.py。请先运行 [Cell 1] 切换到项目根目录！")
# 定义数据集名称
DATASET = "Sports_and_Outdoors"
# 用户指定的数据源路径
RAW_DATA_PATH = "../MiniOneRec-2/data/Amazon/raw"  # 假设 MiniOneRec-2 与当前项目同级
# 或者如果是绝对路径，请按需修改，例如: RAW_DATA_PATH = "/home/user/MiniOneRec-2/data/Amazon/raw"
# 运行数据处理脚本
# !python data/amazon18_data_process.py \
    --dataset {DATASET} \
    --user_k 5 \
    --item_k 5 \
    --st_year 1996 --st_month 10 \
    --ed_year 2018 --ed_month 10 \
    --reviews_file {RAW_DATA_PATH}/{DATASET}_5.json \
    --metadata_file {RAW_DATA_PATH}/meta_{DATASET}.json \
    --output_path ./data/Amazon
print(f"{DATASET} 数据处理完成！请检查 data/Amazon/{DATASET} 目录。")
# Out:
# /root/miniconda3/envs/leejt/lib/python3.12/site-packages/torch/_subclasses/functional_tensor.py:279: UserWarning: Failed to initialize NumPy: module 'numpy._globals' has no attribute '_signature_descriptor' (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:81.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))
# Processing dataset: Sports_and_Outdoors
# Initial time range: 1996-10 to 2018-10
# K-core threshold: 5
# Loading reviews...
# Loaded 2839940 total reviews
# Processing metadata: 100%|██████████| 962300/962300 [00:01<00:00, 609704.62it/s]
# Loaded 962300 metadata items, 914245 with valid titles
# Performing k-core filtering...
# K-core filtering: 100%|██████████| 2839940/2839940 [00:02<00:00, 1021858.78it/s]
# Users: 331672, Items: 95367, Reviews: 2555454, Density: 8.079065647951415e-05
# K-core filtering: 100%|██████████| 2555454/2555454 [00:02<00:00, 1005378.56it/s]
# ...

# %%
import os
# 二次确认当前目录是否正确 (必须在 MiniOneRec-2 根目录下)
if not os.path.exists("data/amazon18_data_process.py"):
    # 尝试自动修正
    if os.path.exists("../../../data/amazon18_data_process.py"):
        os.chdir("../../..")
        print("已自动切换回项目根目录")
    else:
        raise FileNotFoundError(f"错误：当前工作目录是 {os.getcwd()}，找不到 data/amazon18_data_process.py。请先运行 [Cell 1] 切换到项目根目录！")
# 定义数据集名称
DATASET = "Toys_and_Games"
# 用户指定的数据源路径
RAW_DATA_PATH = "../MiniOneRec-2/data/Amazon/raw"  # 假设 MiniOneRec-2 与当前项目同级
# 或者如果是绝对路径，请按需修改，例如: RAW_DATA_PATH = "/home/user/MiniOneRec-2/data/Amazon/raw"
# 运行数据处理脚本
# !python data/amazon18_data_process.py \
    --dataset {DATASET} \
    --user_k 5 \
    --item_k 5 \
    --st_year 1996 --st_month 10 \
    --ed_year 2018 --ed_month 10 \
    --reviews_file {RAW_DATA_PATH}/{DATASET}_5.json \
    --metadata_file {RAW_DATA_PATH}/meta_{DATASET}.json \
    --output_path ./data/Amazon
print(f"{DATASET} 数据处理完成！请检查 data/Amazon/{DATASET} 目录。")
# Out:
# /root/miniconda3/envs/leejt/lib/python3.12/site-packages/torch/_subclasses/functional_tensor.py:279: UserWarning: Failed to initialize NumPy: module 'numpy._globals' has no attribute '_signature_descriptor' (Triggered internally at /pytorch/torch/csrc/utils/tensor_numpy.cpp:81.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))
# Processing dataset: Toys_and_Games
# Initial time range: 1996-10 to 2018-10
# K-core threshold: 5
# Loading reviews...
# Loaded 1828971 total reviews
# Processing metadata: 100%|██████████| 633883/633883 [00:01<00:00, 432669.46it/s]
# Loaded 633883 metadata items, 596621 with valid titles
# Performing k-core filtering...
# K-core filtering: 100%|██████████| 1828971/1828971 [00:01<00:00, 1006384.36it/s]
# Users: 208083, Items: 74272, Reviews: 1710845, Density: 0.00011070033764635351
# K-core filtering: 100%|███████████| 1710845/1710845 [00:01<00:00, 971177.21it/s]
# ...
